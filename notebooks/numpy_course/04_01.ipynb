# %% [markdown]
# Arithmetic operations

# %%
import numpy as np

# %%
a=np.arange(1,11)
b=np.arange(21,31)
print('a',a)
print('b',b)

# %%
a+b

# %%
b-a

# %%
a*b

# %%
b/a

# %%
c=np.arange(2,12)
print('c',c)

# %%
a**c

# %%
a*2

# %%
np.add(a,b)

# %%
np.subtract(b,a)

# %%
np.multiply(a,b)

# %%
np.divide(b,a)

# %%
np.mod(b,a)

# %%
np.power(a,c)

# %%
np.sqrt(a)
