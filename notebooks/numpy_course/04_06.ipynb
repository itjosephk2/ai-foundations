# %% [markdown]
# Reversing an array

# %%
import numpy as np

# %%
arr_one_dim=[10,1,9,2,8,3,7,4,6,5]
arr_one_dim

# %%
arr_one_dim[::-1]

# %%
np.flip(arr_one_dim)

# %%
arr_two_dim=np.arange(9).reshape(3,3)
arr_two_dim

# %%
np.flip(arr_two_dim, axis=1)

# %%
np.flip(arr_two_dim)

# %%
arr_three_dim=np.arange(24).reshape(2,3,4)
arr_three_dim

# %%
np.flip(arr_three_dim, 1)

# %%
np.flip(arr_three_dim, 2)
