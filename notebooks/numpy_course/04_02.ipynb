# %% [markdown]
# Broadcasting

# %%
import numpy as np

# %%
a=np.arange(1,10).reshape(3,3)
a

# %%
b=np.arange(1,4)
b

# %%
a+b

# %%
c=np.arange(1,3)
c

# %%
a+c

# %%
d=np.arange(24).reshape(2,3,4)
d

# %%
e=np.arange(4)
e

# %%
d-e
