# %% [markdown]
# # Python Basics — Index
#
# This track builds a clean Python foundation aimed at data, numerics, and machine learning.
#
# ---
#
# ## 0 — Core Python Foundations
#
# 1. [Variables, Expressions & Basic Types](01_variables_expressions_types.ipynb)
#    - Variables, assignment, integers, floats, booleans
#    - Arithmetic, comparisons, simple expressions
#
# 2. [Control Flow: `if`, `elif`, `else`](02_control_flow_if_else.ipynb)
#    - Conditional logic
#    - Truthiness and boolean operators
#
# ---
#
# ## 1 — Collections & Sequences
#
# 3. [Lists & Tuples](03_lists_and_tuples.ipynb)
#    - Indexing, slicing, mutability
#    - Common list operations
#
# 4. [Dicts, Sets & Loops](04_dicts_sets_and_loops.ipynb)
#    - Dictionaries and sets
#    - `for` / `while` loops and iteration patterns
#
# ---
#
# ## 2 — Functions & Iterables
#
# 5. [Functions & Scope](05_functions_and_scope.ipynb)
#    - `def`, arguments, return values
#    - Local vs global scope
#
# 6. [Iterables, `zip`, and `enumerate`](06_iterables_zip_enumerate.ipynb)
#    - Iterables and iteration protocol
#    - `zip`, `enumerate`, unpacking
#
# ---
#
# ## 3 — Object-Oriented Foundations
#
# 7. [Classes & Instances](07_classes_and_instances.ipynb)
#    - `class`, attributes, methods, `self`
#    - Class vs instance variables
#
# 8. [Inheritance & OOP Patterns](08_inheritance_and_OOP_patterns.ipynb)
#    - Subclassing and overriding
#    - `super()` and method resolution
#
# ---
#
# ## 4 — Numeric Precision & Robustness
#
# 9. [Floating Point & Precision](09_floating_point_and_precision.ipynb)
#    - 0.1 + 0.2 issue
#    - Rounding errors and `math.isclose`
#
# 10. [Errors, Exceptions & Debugging Patterns](10_errors_exceptions_and_debugging_patterns.ipynb)
#     - `try` / `except`
#     - Reading tracebacks, simple debugging habits
